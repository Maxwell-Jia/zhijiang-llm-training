# %%
from datatrove.pipeline.readers import ParquetReader

# %%
data_reader = ParquetReader("hf://datasets/HuggingFaceFW/fineweb-edu", glob_pattern="sample/10BT/*.parquet", limit=100)

# %%
for document in data_reader():
    print(document)
    data = document
# Out:
# 2024-06-04 19:11:25.163 | INFO     | datatrove.pipeline.readers.base:read_files_shard:193 - Reading input file sample/10BT/000_00000.parquet
# ...

# %%
from collections import Counter
from datatrove.executor import LocalPipelineExecutor
from datatrove.pipeline.readers import ParquetReader
from datatrove.pipeline.filters import LambdaFilter, SamplerFilter
from datatrove.pipeline.writers import JsonlWriter
from datatrove.data import DocumentsPipeline

pipeline_exec = LocalPipelineExecutor(
    pipeline=[
        ParquetReader("hf-mirror://datasets/HuggingFaceFW/fineweb-edu", glob_pattern="sample/10BT/*.parquet", limit=10),
        # LambdaFilter(lambda record: add_id(record, counter)),
        # add_id,
        JsonlWriter(output_folder="./test")
    ],
    tasks=1
)
pipeline_exec.run()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 10
#       5 from datatrove.pipeline.writers import JsonlWriter
#       6 from datatrove.data import DocumentsPipeline
#       8 pipeline_exec = LocalPipelineExecutor(
#       9     pipeline=[
# ---> 10         ParquetReader("hf-mirror://datasets/HuggingFaceFW/fineweb-edu", glob_pattern="sample/10BT/*.parquet", limit=10),
#      11         # LambdaFilter(lambda record: add_id(record, counter)),
#      12         # add_id,
#      13         JsonlWriter(output_folder="./test")
#      14     ],
#      15     tasks=1
#      16 )
#      17 pipeline_exec.run()
#
# ...

# %%
import gzip
import json

res = []
with gzip.open("/mnt/geogpt-gpfs/llm-course/home/jiaminghui/zhijiang-llm-training/outputs/fineweb-edu/00000.jsonl.gz") as f:
    for line in f:
        data = json.loads(line)
        res.append(data)
# Out:
# ---------------------------------------------------------------------------
# EOFError                                  Traceback (most recent call last)
# Cell In[51], line 6
#       4 res = []
#       5 with gzip.open("/mnt/geogpt-gpfs/llm-course/home/jiaminghui/zhijiang-llm-training/outputs/fineweb-edu/00000.jsonl.gz") as f:
# ----> 6     for line in f:
#       7         data = json.loads(line)
#       8         res.append(data)
#
# File /mnt/geogpt-gpfs/llm-course/home/jiaminghui/Miniconda3/envs/llm/lib/python3.11/gzip.py:399, in GzipFile.readline(self, size)
#     397 def readline(self, size=-1):
#     398     self._check_not_closed()
# --> 399     return self._buffer.readline(size)
#
# File /mnt/geogpt-gpfs/llm-course/home/jiaminghui/Miniconda3/envs/llm/lib/python3.11/_compression.py:68, in DecompressReader.readinto(self, b)
#      66 def readinto(self, b):
#      67     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68         data = self.read(len(byte_view))
# ...

# %%
len(res)
# Out:
# 10000

# %%
res[789]
# Out:
# {'text': 'The Portable Antiquities Scheme (PAS) exists to record objects found by members of the public and enter them onto an online database. Since it began in 1997, PAS has recorded over 750,000 objects of all periods of history from Palaeolithic flints to eighteenth-century coins and has become an important source of new archaeological data to be used by students and academics in their research. Initially based on a small group of pilot regions, recording was extended to cover the whole of England and Wales in 2003, at which point Oxfordshire became a part of the Scheme with the employment of a local Finds Liaison Officer (FLO) in the county. Alongside recording ordinary objects, PAS also deals with objects which come under remits of the Treasure Act 1996, which include gold and silver artefacts and coin hoards.\nThe Ashmolean has been officially involved with the PAS since 2004 when the Scheme’s ‘National Finds Advisor for Medieval and Post-medieval Coinage’ became a part of our
# ...

# %%
import gzip
import json

file = "/mnt/geogpt-gpfs/llm-course/public/datasets/dolma_v1_7/wiki/documents/wiki-0000.json.gz"

with gzip.open(file, 'rt') as f:
    for line in f:
        data = json.loads(line)
        print(data)
        break
# Out:
# {'added': '2023-04-25T09:58:21.172Z', 'created': '2023-04-25T09:58:21.172Z', 'id': '5', 'metadata': {'length': 541, 'provenance': 'en_simple_wiki_v0-0000.json.gz:1', 'revid': '3382164', 'url': 'https://en.wikibooks.org/wiki?curid=5'}, 'source': 'wikipedia', 'text': 'Organic Chemistry/Cover\n\nWelcome to the world\'s foremost open content&lt;br&gt;Organic Chemistry Textbook&lt;br&gt;on the web!\nThe Study of Organic Chemistry.\nOrganic chemistry is primarily devoted to the unique properties of the carbon atom and its compounds. These compounds play a critical role in biology and ecology, Earth sciences and geology, physics, industry, medicine and — of course — chemistry. At first glance, the new material that organic chemistry brings to the table may seem complicated and daunting, but all it takes is concentration and perseverance. Millions of students before you have successfully passed this course and you can too!\nThis field of chemistry is based less on formulas and more on reacti
# ...

# %%
data
# Out:
# {'added': '2023-04-25T09:58:21.172Z',
#  'created': '2023-04-25T09:58:21.172Z',
#  'id': '5',
#  'metadata': {'length': 541,
#   'provenance': 'en_simple_wiki_v0-0000.json.gz:1',
#   'revid': '3382164',
#   'url': 'https://en.wikibooks.org/wiki?curid=5'},
#  'source': 'wikipedia',
# ...

# %%
import requests
mirror_url = "https://huggingface.co/datasets/HuggingFaceFW/fineweb-edu/resolve/main/sample/10BT/"
file_name = "000_00000.parquet"
response = requests.get(f"{mirror_url}{file_name}")
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File /mnt/geogpt-gpfs/llm-course/home/jiaminghui/Miniconda3/envs/llm/lib/python3.11/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
# ...

# %%
response
# Out:
# <Response [401]>
